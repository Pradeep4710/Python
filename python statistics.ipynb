# %%
#Package / Library / Module

# %%
# Module : Any python program is considered as a module (.py) .

# %%
# Library : Collection of multiple module.
# It will contain lots of functions and variables which be called.
# Functions ---> Method
# Variable ---> Attributes

# %%
# Package  ; It is a directory which contains collections of libraries.

# %%
# Libraries can be devided into two types---
#1 Inbuilt library( python standard library )
# https://docs.python.org/3/library/
#2 User defined library ( use package manager to istall )
# Numpy , Matplotlib , Seaborn , Pandas , Scikit-learn , Tensorflow , Streamlit

# %%
import statistics

# %%
import numpy

# %%
import Streamlit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-2fddcb47474c> in <module>()
# ----> 1 import Streamlit
#
# ModuleNotFoundError: No module named 'Streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#if we have such error it means we have to install this library using  pip install.

# %%
# !pip install streamlit

# %%
#libraries useful for statistics
# 1 Statistics Module from Python Standard Library
# https://docs.python.org/3.7/library/statistics.html
# 2 Numpy Library
# https://numpy.org/doc/stable/
# 3 Scipy Library
# https://docs.scipy.org/doc/scipy/reference/stats.html

# %%
# It contains array as the bassic object
import numpy as np
a = np.array([26,56,27,56,98]) #Method
print(a)
# Out:
# [26 56 27 56 98]

# %%
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
print(a.shape) #Attribute
# Out:
# (5,)

# %%
# Basic arthmatic operations
np.sum(a)
# Out:
# 263

# %%
# Centeral tendency : Average
# Sum of total values devided by total count.
mean_a=np.sum(a)/len(a)
mean_a
# Out:
# 52.6

# %%
#OR
np.mean(a)
# Out:
# 52.6

# %%
#Median : arranging te values in an array inn an order and checking the middle tearm.
# 50th percentile --> Median (2nd quartile)
np.sort(a)
# Out:
# array([26, 27, 56, 56, 98])

# %%
56 #middle value
# Out:
# 56

# %%
np.median(a)
# Out:
# 56.0

# %%
np.mode(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-e8bdc96d903e> in <module>()
# ----> 1 np.mode(a)
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     312
#     313             raise AttributeError("module {!r} has no attribute "
# --> 314                                  "{!r}".format(__name__, attr))
#     315
#     316         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
#We cannot find mode directly with numpy.

# %%
# mode --> Most repeated value in a dataset.

# %%
from scipy import stats
stats.mode(a)
# Out:
# ModeResult(mode=array([56]), count=array([2]))

# %%
#OR 
np.unique(a,return_counts=True)
#we dont get mode directly through numpy
# Out:
# (array([26, 27, 56, 98]), array([1, 1, 2, 1]))

# %%
# Measure of Spread
# Range - Difference between the highest and lowest values
# >Application - Scaling(Normalization)
# Varience - How far the numbers are spread from the average value
# Standard deviation -  Squared root of varience
# >Appication - Standard scaling , Z-score(Outier deviation)

# %%
# Assignment - How centeral tendency and measure of spread are used in data science
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
a = np.array([1,2,3,4])
np.mean(a)
# Out:
# 2.5

# %%
b = np.array([2.5 , 2.5 , 2.5])
np.mean(b)
# Out:
# 2.5

# %%
a = np.array([1,2,2,3,4,5,5,2,3,4])
np.var(a)
# Out:
# 1.69

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
a_mean=np.mean(a)
a_mean
# Out:
# 3.1

# %%
a_var_n = 0
for i in range(len(a)):
  a_var_n = a_var_n + np.square(a[i] - a_mean)
a_var = a_var_n/len(a)
a_var
# a_var_n stands for the numinator part
# Out:
# 1.69

# %%
a_std = a_var**0.5
a_std
# Out:
# 1.3

# %%
# Range
a_min = np.min(a)
a_max = np.max(a)
print(a_max,a_min)
range_a = a_max-a_min
print(range_a)
# Long method to find range
# Out:
# 5 1
# 4

# %%
# Short method to find range
np.ptp(a)
# Out:
# 4

# %%
# Assignment : 1
# Normalisatrion - Scale in the range of (0-1)
age = np.array([52,64,35,66,23,45,23,46,67])
sal = np.array([12300,23400,45000,56000,23500,45000,56000,34500,45600])

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)

# %%
max_age = np.max(age)
min_age = np.min(age)
max_sal = np.max(sal)
min_sal = np.min(sal)
norm_age = (age-min_age)/(max_age-min_age)                
norm_age
# Out:
# array([0.65909091, 0.93181818, 0.27272727, 0.97727273, 0.        ,
#        0.5       , 0.        , 0.52272727, 1.        ])

# %%
norm_sal = (sal-min_sal)/(max_sal-min_sal)
norm_sal
# Out:
# array([0.        , 0.25400458, 0.74828375, 1.        , 0.25629291,
#        0.74828375, 1.        , 0.50800915, 0.76201373])

# %%
# Assignment : 2
# Take 2 numpy arrays (2 points on coordinate geometry).
# Euclidean distance on 2 points to get distance as the output.

# %%
a = np.array([34,45])
b = np.array([29,41])
np.sqrt(np.sum(np.square(np.subtract(a,b))))
# Out:
# 6.4031242374328485

# %%
# OR
np.linalg.norm(a-b)
# Out:
# 6.4031242374328485

# %%
# Regression loss function
# Mean square error
# Mean absolute error

# %%
import numpy as np

# %%
y_real = np.array([33,21,12,22])
y_pred1 = np.array([32.83547606, 20.90990165, 11.76837935, 21.38974336])
y_pred2 = np.array([32,20,11,21])
mse1 = np.mean(np.square(np.subtract(y_real,y_pred1)))
mse1
# Out:
# 0.11531178291908961

# %%
mse2 = np.mean(np.square(np.subtract(y_real,y_pred2)))
mse2
# Out:
# 1.0

# %%
# Pandas : Exploratory Data Analysis
# 2 main objects
# Series - 1 Dimension (1 column/1 row) --> Vectors in Numpy
# Dataframe - 2 Dimensions - Matrix in Numpy

# %%
d = {'name':['Mr X','Mr Y','Mr Z','Mr A','Mr B'],
     'Height':[123,145,167,124,156],
     'Weight':[56,34,78,45,67]}
d
# Out:
# {'Height': [123, 145, 167, 124, 156],
#  'Weight': [56, 34, 78, 45, 67],
#  'name': ['Mr X', 'Mr Y', 'Mr Z', 'Mr A', 'Mr B']}

# %%
import pandas as pd
df = pd.DataFrame(d)
df
# Out:
#    name  Height  Weight
# 0  Mr X     123      56
# 1  Mr Y     145      34
# 2  Mr Z     167      78
# 3  Mr A     124      45
# 4  Mr B     156      67

# %%
df.shape
# Out:
# (5, 3)

# %%
df.describe()
# Out:
#            Height     Weight
# count    5.000000   5.000000
# mean   143.000000  56.000000
# std     19.429359  17.392527
# min    123.000000  34.000000
# 25%    124.000000  45.000000
# 50%    145.000000  56.000000
# 75%    156.000000  67.000000
# max    167.000000  78.000000

# %%
np.mean(df['Height'])
# Out:
# 143.0

# %%
# Datab visualisation : Matplotlib , Seaborn , Plotly
# 1. Line Grapg
# 2. Bar Graph
# 3. Pie chart
# 4. Scatter plot
# 5. Histogram

# %%
import matplotlib.pyplot as plt
a = np.array([2,5,6,2,45,23])
b = np.array([5,8,34,89,34,4])
plt.plot(a,b,marker='o')
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.show()

# %%
  a = np.array([1,2,3])
  b = np.array([1,8,27])
  a = (b*b*b)
  plt.plot(a,b)
  plt.show()

# %%
# BAR GRAPH
plt.bar(df['name'],df['Height'])
plt.show()

# %%
 plt.bar(df['name'],df['Weight'])
plt.show()

# %%
# We can also see combined graphs (stack bars)
plt.bar(df['name'],df['Height'],label='Height')
plt.bar(df['name'],df['Weight'],label="Weight")
plt.legend()
plt.show()

# %%
#Pie chart

cities = np.array(['bangalore','chennai','kokata','delhi'])
sales = np.array([2233,3344,2245,4466])
plt.pie(sales , labels=cities , autopct='%.2f')
plt.show()

# %%
plt.pie?

# %%
# Scatterplot
plt.scatter(df['Height'],df['Weight'])
plt.show()

# %%
# Histogram
x = np.random.normal(100,10,250)
plt.hist(x)
plt.show()
