# %%
# Python important topics
# 1. Inbilt fumctions , variable and datatypes.
# 2. Type casting and string formatting.
# 3. Conditions.
# 4. Loops.
# 5. Data structure.
# 6. Functions.

# %%
print("hello world")
# Out:
# hello world

# %%
a = 1
print(a)
print(type(a))
# Out:
# 1
# <class 'int'>

# %%
b = 1.1
print(b)
print(type(b))
# Out:
# 1.1
# <class 'float'>

# %%
c = 1
d = 1.1
e = 'A'
f = 'Python is awsome'
g = "python"
h = True

print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))

#OR

print(type(c),type(d),type(e),type(f),type(g),type(h))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'int'> <class 'float'> <class 'str'> <class 'str'> <class 'str'> <class 'bool'>

# %%
#datatypes and variables consume daataspace.
#we can get memory address of it by-
print(id(a))
# Out:
# 94177515612672

# %%
#Type casting : changeing one datatype to another data type.
a = 'PY'
b = 'THON'
print(a+b)

#joining 2 strings is called 'concatination'.
# Out:
# PYTHON

# %%
x = '3'
y = '2'
print(type(x) , type(y))
print(x+y)
print(x,y)
# Out:
# <class 'str'> <class 'str'>
# 32
# 3 2

# %%
#joining 2 integer values-
x = '3'
x = int(x)
y = '2'
y = int(y)
print(type(x) , type(y))
print(x+y)
print(x,y)
# Out:
# <class 'int'> <class 'int'>
# 5
# 3 2

# %%
#Taking input from user.
sub = input()
print("I am stydying",sub)
# Out:
# python
# I am stydying python

# %%
#Assignment-take 2 numbers from user as input , add them and show the output.

# %%
22#With the help of type casting
num1 = int(input("enter the first number-"))
num2 = int(input("enter the second number-"))
add = num1 + num2
print("the sum is=",add)
# Out:
# enter the first number-21
# enter the second number-29
# the sum is= 50

# %%
# String Formatting
#the number is 34
#Method 1
a = 34
print("the number is",a)
# Out:
# the number is 34

# %%
#Method 2
a = 34
print("the number is " +str(a))
# Out:
# the number is 34

# %%
#method 3
print(f"the number is {a}")
# Out:
# the number is 34

# %%
 print(f'the sum of {num1} and {num2} is {add}')
# Out:
# the sum of 21 and 29 is 50

# %%
#condition
# Boolean datatype : true anf false
# is , elif(else if) , else

#To check if number n is odd or even.
n = int(input("enter the number "))
if n%2==0: 
  print(f"the number {n} is even")
else:
  print(f"the number {n} is odd")
# Out:
# enter the number 69
# the number 69 is odd

# %%
# Take input from the user
# weather 
# sunny - Summer Season
# cold - Winter season
# rain - monsoon season
# anything else - Wrong input

# %%
weather = input("Enter the weather: ").lower()
if weather =='sunny' or weather =='hot':
  print("It is summer season")
elif weather == 'cold' or weather =='chill':
  print("It is winter season")
elif weather =='rain' or weather =='thunder' or weather =='lightning':
  print("It is monsoon season")
else:
  print("Wrong input")
# Out:
# Enter the weather: hot
# It is summer season

# %%
# 3 logical operators in python
# 1. and
# 2. or
# 3. not

# %%
# Loop constructs
# 1. Finite 
# 2. Infinite

# 1. Entry controlled loop - while, for
# 2. Exit controlled loop - do while

# %%
# While loop
# 1. Initilization
# 2. Condition
# 3. Increment/Decrement (Steps)

# %%
# Print Python 5 times

i = 0
while i<5:
  print("Python")
  i=i+1  # Cant write i++, but can use shorthand operators
# Out:
# Python
# Python
# Python
# Python
# Python

# %%
print(5*'Python\n')
# Out:
# Python
# Python
# Python
# Python
# Python

# %%
i = 0
while i<5:
  print(i)
  i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Take input number from the user and print multiplication table
n = int(input("Enter the number"))
i = 1
while i<=10:
  print(f'{n} X {i} = {n*i}')
  i+=1
# Out:
# Enter the number5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
# range - from source to destination

range(3)
# Out:
# range(0, 3)

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(2,6):
  print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
for i in range(1,12,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
#Data structures:List , tuple , dictionary.

# %%
a = 12
print(a)
# Out:
# 12

# %%
b = 12,13,14,15
#b = (12,13,14,15)
print(b)
print(type(b))
# Out:
# (12, 13, 14, 15)
# <class 'tuple'>

# %%
b = [12,13,14,15]
print(b)
print(type(b))
# Out:
# [12, 13, 14, 15]
# <class 'list'>

# %%
# Difference between list and tuple
# 1. List are mutable(changes) objects , tuples are immutable(no changes)
# 2. Tuples are more memory efficient object

# %%
# List and its methods
list_a=[97,98,99,100]
list_a[0]
# Out:
# 97

# %%
#Positive indexing
list_a[3]
# Out:
# 100

# %%
#Negative indexing
list_a[-1]
# Out:
# 100

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
#slicing
list_a[0:3]
# Out:
# [97, 98, 99]

# %%
list_a[-3:-1]
# Out:
# [98, 99]

# %%
list_a=[97,98,99,100]
list_a[1] = 104
list_a
#value is updated in list
# Out:
# [97, 104, 99, 100]

# %%
#lets try to update value in tuple.

tuple_a=(1,2,3,4)
tuple_a[2]=7
tuple_a
#we cant update value in tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-70c4f5265f0e> in <module>()
#       2
#       3 tuple_a=(1,2,3,4)
# ----> 4 tuple_a[2]=7
#       5 tuple_a
#       6 #we cant update value in tuple
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
list_a=[97 , 98 , 99 , 100]
list_a.append(101)
list_a
# Out:
# [97, 98, 99, 100, 101]

# %%
list_a.remove(99)
list_a
# Out:
# [97, 98, 100, 101]

# %%
#How to take input from user.
list_z=[]
length = int(input("length of list"))
for i in range(length):
  list_z.append(int(input()))
list_z
# Out:
# length of list5
# 4
# 3
# 2
# 1
# 0
# [4, 3, 2, 1, 0]

# %%
#[2,3,python,5]
list_z=[]
length = int(input("length of list"))
for i in range(length):
  list_z.append(input())
list_z
# Out:
# length of list4
# 2
# 3
# python
# 5
# ['2', '3', 'python', '5']

# %%
list_x=[86,89,89,90]
list_y=list_x
list_y[2]=100
list_x
#will the value of list x also change?
#ANS-YES
# Out:
# [86, 89, 100, 90]

# %% [markdown]
# REASON![Screenshot 2022-04-16 201942.png](data:image/png;base64,...)

# %%
#BUT for .copy
list_x=[86,89,89,90]
list_y=list_x.copy()
list_y[2]=100
list_x
#the values in original list_x stays the same
# Out:
# [86, 89, 89, 90]

# %% [markdown]
# REASON![Screenshot 2022-04-16 202309.png](data:image/png;base64,...)

# %%
#Quick ways to create lists.
list(list_x)
# Out:
# [86, 89, 89, 90]

# %%
list(range(3))
# Out:
# [0, 1, 2]

# %%
list(range(2,10))
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
list(range(2,6,2))
# Out:
# [2, 4]

# %%
#Dictionary
#key : value pair
#{}

# %%
d={'name':'Amir'}
print(d)
print(type(d))
# Out:
# {'name': 'Amir'}
# <class 'dict'>

# %%
d1 = {'name':['Amir , Greeb'] , 'height':['124,145']}
d1
# Out:
# {'height': ['124,145'], 'name': ['Amir , Greeb']}

# %%
#OR
person = ['Amir , Gareeb']
d1 = {'name':person , 'height':['124,145']}
d1
#Output in dictionary is random , it is not ordered.
# Out:
# {'height': ['124,145'], 'name': ['Amir , Gareeb']}

# %%
d1.keys()
# Out:
# dict_keys(['name', 'height'])

# %%
d1.values()
# Out:
# dict_values([['Amir , Gareeb'], ['124,145']])

# %%
d1['height']
# Out:
# ['124,145']

# %%
d1['name']
# Out:
# ['Amir , Gareeb']

# %%
#List Comprehension(matplotlib)

# %%
#Functions - Inbuilt functions AND User defined functions
#1. Function Decleration
#2. Function Call

# %% [markdown]
# Inbuilt functions that we touched in session![Screenshot 2022-04-16 205017.png](data:image/png;base64,...)

# %%
def func1(x):
  return x
func1(input('enter the data'))
# Out:
# enter the datapython
# 'python'

# %%
 #in tuple
 def func1(x):
  op = "My expertise is in"
  return op , x
func1(input('Enter your expertise'))
# Out:
# Enter your expertise python
# ('My expertise is in', ' python')

# %%
#in formatted string
def func1(x):
  op = "My expertise is in"
  return f'{op} {x}'
func1(input('Enter your expertise'))
# Out:
# Enter your expertise python
# 'My expertise is in  python'

# %%
# write a program to add 2 numbers and display the output
x = int(input())
y = int(input())

def add(a,b):  
  print(a+b)

add(x,y)
# Out:
# 4
# 6
# 10
