# %% [markdown]
# # Getting and Knowing your Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable.

# %%
URL= 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
df = pd.read_table(URL)

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?
# ### 1 How many rows and columns?
# #### 2 Print the column names

# %%
# Solution 1
df.shape
# Out:
# (4622, 5)

# %%
# Solution 2
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 6. Slicing between rows

# %%
df[5:11]
# Out:
#     order_id  quantity            item_name  \
# 5          3         1         Chicken Bowl
# 6          3         1        Side of Chips
# 7          4         1        Steak Burrito
# 8          4         1     Steak Soft Tacos
# 9          5         1        Steak Burrito
# 10         5         1  Chips and Guacamole
#
#                                    choice_description item_price
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                NaN     $4.45

# %% [markdown]
# ### Step 7. Getting Subset of DataFrame/ Series
#
# #### Hint : Learn about .iloc operator

# %%
df[['item_name' , 'item_price']]
# we use double brackets to write it as a list or otherwize it will show error while printing 2 columns
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# df.iloc[rows,columns]
df.iloc[: , [2,4]]
# : is used to include all values
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 8. Check for duplicates and drop them

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Length: 4622, dtype: bool

# %%
df[df.duplicated()]
# Out:
#       order_id  quantity                            item_name  \
# 238        103         1                        Steak Burrito
# 248        108         1                          Canned Soda
# 297        129         1                        Steak Burrito
# 381        165         1                    Canned Soft Drink
# 484        205         1                         Chicken Bowl
# 567        233         1                    Canned Soft Drink
# 617        254         1                                Chips
# 684        282         1                    Canned Soft Drink
# 773        319         1                         Chicken Bowl
# 908        376         1                        Steak Burrito
# 924        381         1                   Chicken Soft Tacos
# 1003       412         1                        Bottled Water
# 1117       462         1                      Chicken Burrito
# 1203       491         1                      Chicken Burrito
# ...

# %%
len(df[df.duplicated()])
# Out:
# 59

# %%
df=df.drop_duplicates()
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
df['item_name'].value_counts()
# Out:
# Chicken Bowl                             717
# Chicken Burrito                          546
# Chips and Guacamole                      474
# Steak Burrito                            365
# Canned Soft Drink                        290
# Steak Bowl                               210
# Chips                                    208
# Bottled Water                            155
# Chicken Soft Tacos                       111
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              102
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          90
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             65
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
df['item_name'].value_counts().head(1)
# Out:
# Chicken Bowl    717
# Name: item_name, dtype: int64

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df['choice_description'].value_counts().head(1)
# Out:
# [Diet Coke]    133
# Name: choice_description, dtype: int64

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
df['quantity'].sum()
# Out:
# 4913

# %%
df['quantity'].value_counts()
# Out:
# 1     4296
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 12a. Get the details of highest ordered item
# #### Hint : Use Conditions

# %%
df['quantity'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 4617    1
# 4618    1
# 4619    1
# 4620    1
# 4621    1
# Name: quantity, Length: 4563, dtype: int64>

# %%
h_quantity=df['quantity'].max()
df[df['quantity']==h_quantity]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
df['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4563, dtype: object

# %%
df['item_price'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Step 13.b. Change the type of item price to float

# %%
df['item_price']=df['item_price'].str.replace('$','').astype('float')
# Out:
# <ipython-input-24-a58148caaa7f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price']=df['item_price'].str.replace('$','').astype('float')

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
df['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
# This is not the final revenue its only for sinle quantity of each item.
df['item_price'].sum()
# Out:
# 34177.25

# %%
# F for real revenue.
revenue = (df['item_price']*df['quantity']).sum() 
revenue
# Out:
# 38914.11

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
df['order_id'].nunique()
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
np.mean(df['item_price']*df['quantity'])
#this is not the average revenue as it calculates revenue per item not per order. Hence using this method is wrong.
# Out:
# 8.52818540433925

# %%
revenue/1834
# Out:
# 21.218162486368595

# %%
# lets take example for average revenue for orders with quantity = 4.
df4 = df[df['quantity']==4]
r_4 = df4['item_price']*df4['quantity']
r_4.sum()
# Out:
# 523.8399999999999

# %%
df4['order_id'].nunique()
# Out:
# 7

# %%
#revenue per order for orders with quantity=4
523.839999999999/7
# Out:
# 74.83428571428557

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
df['item_name'].nunique()
# Out:
# 50

# %%
#Task : How many orders have revenue less than 10 dollars

# %%
len(df[(df['item_price']*df['quantity'])<10])
# Out:
# 3386

# %%
# Use a composition graph ( Pie Chart ) and plot the following:
# low = lesser than 5 dollars
# high = greater than 10 dollars
# medium = in between low and high

# %%
# Steps for the analysis
# Step 1: Create a revenue column by multiplying the values of item and quantity from df
# Step 2: Check the length of values having low, high and medium ( Total shld be 4622)
# NoTE : Use & operator to get condition for medium.
# Step 3: Plot a pie chart

# %%
df['revenue']=df['quantity']*df['item_price']

# %%
low = len(df[df['revenue']<5])
low
# Out:
# 1547

# %%
high = len(df[df['revenue']>10])
high
# Out:
# 1177

# %%
med = 4563 - (low+high)
med
# Out:
# 1839

# %%
# OR
bc = df['revenue']>=5
mc = df['revenue']<=10
medium = len(df[(bc)&(mc)])
medium
# Out:
# 1839

# %%
plt.pie([low,medium,high],labels=['low','medium','high'] , autopct='%.2f%%')
plt.show()

# %%
#to cross check if the total revenue is still 4563 or not
revenue = low + medium + high
revenue
# Out:
# 4563
